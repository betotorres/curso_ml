# %% [markdown]
# #Curso de Análise e Ciência de Dados com Python
# Versão 2.1 - 10/09/2023
#
# Autor: Alberto Torres
#
# E-mail: alberto.torres@redes.unb.br

# %% [markdown]
# **Nome do Aluno:** *Digite aqui o seu nome*
#
# **Matrícula:** *Digite aqui a sua matricula*

# %% [markdown]
# #Revisão Aula 01
#
# **Problema 1** -Escreva um programa que alterne os valores armazenados nas variáveis x e y.
#
# Seu programa deve funcionar para diferentes entradas. por exemplo. qualquer valor de x e y.
#
# **Não altere os dados já informados no código abaixo:**
#
# ![image.png](data:image/png;base64,...)

# %%
#Resolução do problema 3

# 🚨 Nao altere o codigo abaixo👇
x = input("x: ")
y = input("y: ")
# 🚨 Nao altere o codigo acima 👆

####################################
#Escreve seu codigo abaixo desta linha 👇




#Escreve seu codigo acima desta linha 👆
####################################

# 🚨 Nao altere o codigo abaixo 👇
print("x: " + x)
print("y: " + y)
# Out:
# x: 1
# y: 2
# x: 2
# y: 1

# %% [markdown]
# #Seção 1 -Tipos e Estruturas de Dados

# %% [markdown]
# ## 1.1. Tipos de Dados Integrados
#
# Uma variável é geralmente associada a um tipo de dado. Em python, a variáveis são dinamicamente tipadas, ou seja, o programador não precisa definir explicitamente o tipo da variável, ele é inferido pelo interpretador no momento em que se atrubui um valor a variável.Além disto, o python também é definido como uma liguagem fortemente tipada. Assim, o interpretador python não executa coerções automáticas entre tipos incompatíveis, ou seja, por mais que o valor de uma variável seja mutável, o seu tipo não é automaticamente alterado pelo python.
#
# O python possui uma variedade de tipos de dados, neste primeiro momento, iremos abordar alguns dos mais essenciais, são eles:
#
# ![image.png](data:image/png;base64,...)
#
# Uma lista completa com todos os tipos de dados pode ser obtida em - https://www.w3schools.com/python/python_datatypes.asp

# %% [markdown]
# ## 1.2. Strings
#
# Não apenas em Python, mas em qualquer linguagem de programação, strings são um conceito indispensável. Uma string em Python é uma **sequência de caracteres**, como letras, números e símbolos, cercadas por aspas simples (' '), duplas (" ") ou triplas (''' ''' ou """ """). Essas sequências  de caracteres podem representar qualquer coisa, desde palavras e frases simples até dados complexos.
#
# Strings em Python não são usadas apenas para representar texto, mas também servem como um tipo de dados fundamental para uma ampla gama de tarefas. Esteja você trabalhando em processamento de texto, análise de dados, desenvolvimento web ou até mesmo inteligência artificial, um conhecimento sólido de strings em Python é essencial.
#
# Strings Python são altamente flexíveis e oferecem uma infinidade de operações e métodos de manipulação. É possível concatenar strings, realizar pesquisas de substrings dentro de substrings, substituir texto, dividir strings em listas, dentre outras operações.
#
# Dentre as principais características das Strings em python, podemos citar:
#
#
#
# *   **Imutável**: Strings em Python são imutáveis, o que significa que você não pode alterar diretamente os caracteres dentro de uma string. Qualquer operação que pareça modificar uma string, na verdade, cria uma nova string.
# * **Indexação e fatiamento**: você pode acessar caracteres individuais em uma string usando índices e extrair substrings usando fatiamento, um recurso poderoso que permite trabalhar com partes específicas de uma string.
# * **Formatação de strings**: O Python oferece várias maneiras de formatar strings, incluindo a formatação tradicional (%), o método str.format() e as strings "f" (strings literais formatadas).
# * **Caracteres de escape**: Pode-se  usar caracteres de escape como \n para nova linha, \t para tabulação e \\ para representar uma barra invertida literal dentro de strings.
# * **Strings brutas**: prefixar uma string com r ou R cria uma string bruta, que trata barras invertidas como caracteres literais e é frequentemente usada para expressões regulares e caminhos de arquivo.
# * **Concatenação de Strings**: Você pode combinar strings usando o operador + ou simplesmente colocando-as adjacentes umas às outras.
# * **Métodos de string**: Python  fornece uma variedade de métodos de string integrados para realizar operações comuns como pesquisa, substituição, formatação e conversão de maiúsculas e minúsculas com facilidade.
#
# Compreender strings Python é uma habilidade fundamental para qualquer desenvolvedor Python. Seja manipulando dados baseados em texto, construindo interfaces de usuário ou processando arquivos, as strings estão no centro de muitas tarefas. Alguns exemplos de Strings são apresentados a seguir:

# %%
#usando aspas simples e duplas
exemplo_string_1 = "este texto 'corresponde a um valor' do tipo string "
print(exemplo_string_1)

#usando caracteres de escape
exemplo_string_2 = ' \t este texto "corresponde" uma string \n'
print(exemplo_string_2)

#exemplo de strings brutas
#raw
exemplo_string_3 = r' \t este texto "corresponde" uma string \t'
print(exemplo_string_3)
# Out:
# este texto 'corresponde a um valor' do tipo string
#  	 este texto "corresponde" uma string
#
#  \t este texto "corresponde" uma string \t

# %%
#imprima um texto com tabulação no inicio





#imprima um texto com que contenha a string \n
# Out:
# 	 Conteudo da celula
# Conteudo da celula
#
# Conteudo da celula \n

# %% [markdown]
# ###1.2.1. Formatação e Concatenação de Strings
#
# A formatação e concatenação de strings são técnicas essenciais de manipulação de strings em python. A **concatenação de strings** é o processo de combinar duas ou mais strings em uma única string. Em Python, existem várias maneiras de concatenar strings:
#
# * **Usando o operador +**: Você pode usar o operador + para concatenar strings
# * **Usando várias strings juntas**: Pode-se simplesmente colocar vários literais de string juntos e o Python irá concatená-los
# * **Usando strings f (literais de string formatados)**: As strings F fornecem uma maneira concisa e poderosa de concatenar strings e incluir variáveis ou expressões dentro da string. Você pode criar uma string f prefixando a string com um caractere 'f' ou 'F' e colocando variáveis ou expressões entre chaves {}.

# %%
#Concatenando Strings com +
nome = 'Joao'
sobrenome = 'Silva'
nome_completo = nome + ' ' + sobrenome
print(nome_completo)

#Usando multiplas strings juntas
nome = 'Joao', ' ', "Silva"
print(nome_completo)

#Usando f-strings
nome = 'Joao'
sobrenome = 'Silva'
nome_completo = f'{nome} {sobrenome}'
print(nome_completo)
# Out:
# Joao Silva
# Joao Silva
# Joao Silva

# %%
var1, var2 = input(), input()
print(int(var1) + int(var2))
# Out:
# 1
# 2
# 3

# %% [markdown]
# Já a formatação de string permite criar strings formatadas inserindo valores em um modelo de string. Python oferece vários métodos para formatação de strings:
#
# * **Usando %**: Pode-se usar a formatação % para inserir valores em um modelo de string. Isso é particularmente útil ao trabalhar com código Python mais antigo, já que as versões mais novas já possuem as f-strings:
#
# * **Usando o método str.format()**: O método str.format() permite inserir valores em uma string usando espaços reservados entre chaves {}:
#
# * **Usando strings f (literais de string formatados)** : Conforme mencionado anteriormente, strings f fornecem a maneira mais concisa e legível de formatar strings, incorporando diretamente variáveis ou expressões na string.

# %%
# Usando %
nome = "Joao"
saudacao = "Olá, %s" % nome
print(saudacao)

# Usando  str.format()
nome = "Joao"
saudacao = "Olá, {}".format(nome)
print(saudacao)

# Usando  f-strings
nome = "Joao"
saudacao = f"Olá, {nome}"
print(saudacao)
# Out:
# Olá, Joao
# Olá, Joao
# Olá, Joao

# %% [markdown]
# ###1.2.2. Indexação de Fatiamento de Strings
#
# Um dos recursos poderosos das strings em Python é a capacidade de trabalhar com fatiamento de strings. As fatias de string permitem extrair substrings de uma determinada string especificando um intervalo de índices.
#
# Para criar uma fatia de string, utiliza-se a seguinte sintaxe:
#
# `string[inicio:fim:step]`
#
# *   inicio: O índice no qual a fatia começa. É inclusivo, o que significa que o caractere neste índice está incluído na fatia.
# * fim: o índice no qual a fatia termina. É exclusivo, o que significa que o caractere neste índice não está incluído na fatia.
# * step (opcional): O valor do passo indica quantos caracteres pular entre cada caractere na fatia. O valor padrão é 1, o que significa que caracteres consecutivos estão incluídos.
#
# Abaixo seguem alguns exemplos de fatiamemto de strings

# %%
nome = 'Joao da Silva Sauro'

#Imprime do primeiro ao sétimo caractere
print(nome[0:58])

#Imprime do quinto ao sétimo caractere
print(nome[5:8])

#Imprime do primeiro ao sétimo caractere, com step de 2 caracteres.
print(nome[0:8:2])
# Out:
# Joao da Silva Sauro
# da
# Ja a

# %% [markdown]
# Pode-se, ainda, omitir o inicio e o fim. No caso da omissão do valor de inicio, tem-se por padrão o valor 0. Em caso de omissão do valor de fim, tem-se por padrão o final da string.

# %%
nome = 'Joao da Silva Sauro'

#Imprime do primeiro ao sétimo caractere
print(nome[:8])

#Imprime do quinto ao último caractere
print(nome[5:])
# Out:
# Joao da
# da Silva Sauro

# %% [markdown]
# Há, ainda, a opção de se utilizar índices negativos. Os í**ndices negativos **em Python são um recurso conveniente que permite acessar elementos do final e não do início. A indexação negativa começa em -1 para o último elemento, -2 para o penúltimo elemento e assim por diante, retrocedendo na sequência.
#
# Por exemplo, se você tiver uma string "Python", poderá acessar o último caractere 'n' usando -1 como índice:

# %%
nome = 'Python'

#imprima do primeiro ao penultimo caractere
print(nome[:-1])

#extraia os ultimos dois caracteres
print(nome[-2:])
# Out:
# Pytho
# on

# %% [markdown]
# ###1.2.3. Métodos de String

# %% [markdown]
# São muitas as operações intrínsecas o python que podem ser aplicadas sobre variáveis do tipo string. **Todos os métodos de string retornam novas strings, diferentea das originais. Eles não alteram a string original, já que estas são imutáveis**.
#
# Destacamos, as seguir, alguns dos  principais métodos:

# %%
#Transforma a primeira letra em maiúscula
print(exemplo_string_1.capitalize())

#Tr2ansforma todo o texto em maiúsculas
print(exemplo_string_1.upper())

#Converte a primeira letra de cada uma das palabras para maiúscula
print(exemplo_string_1.title())

#Converte todo o texto para minúsculas
print(exemplo_string_1.lower())

#Remove espaços em branco do lado direito
exemplo_string_1.rstrip()

#Remove espaços em branco do lado esquerdo
exemplo_string_2.lstrip()

#Remove espaços em branco de ambos os lados
print(exemplo_string_2.strip())

#Remove prefixo
exemplo_http = 'https://www.com.br'
print(exemplo_http.removeprefix('https://'))

#Remove sufixo
exemplo_doc = 'arquivo_teste.doc'
print(exemplo_doc.removesuffix('.doc'))

#Retorna True se todos os caracteres são numericos
exemplo_string_2.isnumeric()

#Cria uma lista de multiplos elementos a partir de um determinado separador
exemplo_string_2.split(' ')

#Altera parte do valor da String
exemplo_string_2.replace('este texto', 'ALTERADO')

#Faz a busca de uma substring na string, retornando a posição ou -1, se não encontrar
exemplo_string_2.find('texto')

#uma lista completa de metodos relacionados a Strings poide ser obtida em
#https://www.w3schools.com/python/python_ref_string.asp
# Out:
# Este texto 'corresponde a um valor' do tipo string
# ESTE TEXTO 'CORRESPONDE A UM VALOR' DO TIPO STRING
# Este Texto 'Corresponde A Um Valor' Do Tipo String
# este texto 'corresponde a um valor' do tipo string
# este texto "corresponde" uma string
# www.com.br
# arquivo_teste
# 8

# %% [markdown]
# ### Atividade 1 - Uso de Strings
#
# a) Use uma variável para representar o nome de uma pessoa e imprima uma mensagem para essa pessoa. Sua mensagem deve ser simples, como “Olá Eric, gostaria de aprender um pouco de Python hoje?”
#
# b) Use uma variável para representar o nome de uma pessoa e, em seguida, imprima o nome dessa pessoa com todas as letras minúsculas. Na sequência, imprima todas as letras maiúsculas e, por fim, apenas as iniciais de cada palavra em maiúscula.
#
# c) encontre uma citação de uma pessoa famosa que você admira. Imprima a citação e o nome de seu autor. Sua saída deve ser algo como o seguinte, "incluindo as aspas":
#
#     *Albert Einstein disse uma vez: “Uma pessoa que nunca cometeu um erro nunca tentou nada novo”.*
#
# d) Repita o Exercício "c", mas desta vez, represente o nome da pessoa famosa usando uma variável chamada `pessoa_famosa`. Em seguida, refaça a composição de sua mensagem e represente-a com uma nova variável chamada `mensagem`. Imprima sua mensagem.
#
# e) Use uma variável para representar o nome de uma pessoa e inclua alguns caracteres de espaço em branco no início e no final do nome. Certifique-se de usar cada uma das combinações de caracteres "\t" e "\n" pelo menos uma vez.
#
# f) Imprima o nome armazenado na atividade "e" uma vez, para que o espaço em branco ao redor do nome seja exibido. Em seguida, imprima o nome usando cada uma das três funções de remoção, lstrip(), rstrip() e strip().
#
# g) Atribua o valor `python_notes.txt` a uma variável chamada `nome_arquivo`. Em seguida, programe um método para exibir o nome do arquivo sem a extensão do arquivo, como fazem alguns navegadores de arquivos.

# %%
#Resposta Atividade 1
# Out:
# Olá Eric, gostaria de aprender um pouco de Python hoje?
# Eric da silva santos
# ERIC DA SILVA SANTOS
# eric da silva santos
# Eric Da Silva Santos
# Albert Einstein disse uma vez: "Uma pessoa que nunca cometeu um erro nunca tentou nada novo"
# 	Alberto Einsten disse uma vez: "Uma pessoa que nunca cometeu um erro nunca tentou nada novo"
# Alberto Einsten disse uma vez: "Uma pessoa que nunca cometeu um erro nunca tentou nada novo"
# python_notes

# %% [markdown]
# ### Atividade 2- Uso de Strings

# %% [markdown]
# **Problema 1** - Escreva um código que imprima as mensagens conforme apresentado abaixo:
#
# **Código 1**
#
# ![image.png](data:image/png;base64,...)
#
# **Código 2**
#
# ![image.png](data:image/png;base64,...)

# %%
#Resposta Problema 1

# %% [markdown]
# **Problema 2** - Escreva um programa que imprima o número de caracteres do nome de um usuário. Talvez você precise procurar no Google uma função que calcule o comprimento de uma string.
#
# por exemplo.
#
# https://www.google.com/search?q=como+saber+o+tamanho+de+uma+string+em+python
#
# Aviso. Seu programa deve funcionar para diferentes entradas. por exemplo. qualquer nome que você inserir.
#
# ![image.png](data:image/png;base64,...)

# %%
#Resposta Problema 2
# Out:
# Digite uma entrada: Teste do teste
# 14

# %% [markdown]
# # 1.2. Tipos de Dados Numéricos
#
# Os dados numéricos desempenham um papel fundamental em praticamente todos os aspectos da programação e análise de dados. Em Python, são diversos os tipos de dados e bibliotecas disponíveis para trabalhar com dados numéricos. Neste momento, apresentaremos apenas os dados numéricos internos a própria base da linguagem.
#
# O Python oferece vários tipos de dados numéricos, os mais usados são:
#
# * **inteiros (int)**: São números inteiros sem vírgula decimal. O tipo de dados int do Python pode representar números inteiros positivos e negativos de comprimento não limitado, ou seja, o valor de um inteiro não é restrito por um número de bits de modo que pode ser  expandido até o limite da memória disponível.
# * **floats (float)**:  representam números com ponto decimal. Eles também podem representar números muito grandes ou muito pequenos usando notação científica.
# * **Números Complexos (complexo)**: Os números complexos consistem em uma parte real e uma parte imaginária. Eles são úteis em aplicações científicas e de engenharia.
#
# Na sequência, vamos iniciar a nossa prática trabalhando com números  em python. Antes disto, porém, é importante que conheça o comando type- que  retorna o tipo de dados associado a uma variável. A sua sintaxe é:
#
# > `print(type(nome_da_variavel))`
#
# Vamos, então, aos exemplos

# %%
#valores int
idade = 25
estoque = -78
print(estoque)
print(type(estoque))

#valores float
preco = 17.8

prejuizo = -22.1
print(prejuizo)
print(type(prejuizo))

#valores complex
z = 2 + 3j
print(z)
print(type(z))
# Out:
# -78
# <class 'int'>
# -22.1
# <class 'float'>
# (2+3j)
# <class 'complex'>

# %% [markdown]
# ### Operadores aritméticos básicos
#
# As operações aritméticas são operações matemáticas fundamentais realizadas em tipos de dados numéricos em Python. Essas operações permitem manipular e calcular valores numéricos. Dentre as principais operações, destacamos:
#
# 1. **Adição (+)**: O operador (+) soma dois ou mais números. É usado apenas para adicionar números inteiros e flutuantes, mas também para concatenar strings. a + b
# 2. **Subtração (-)**: O operador (-) subtrai o operando direito do operando esquerdo. a - b
# 3. **Multiplicação (*)**: O operador (*) multiplica dois ou mais números. a * b
# 4. **Divisão (/)**: O operador de divisão (/) realiza a divisão entre o operando esquerdo e o operando direito. No Python 3, ele retorna um float mesmo para divisão inteira. a / b
# 5. **Divisão inteira (//)**: O operador de barra dupla (//) realiza a divisão inteira, que trunca a parte decimal e retorna um resultado inteiro.  a // b
# 6. **Módulo (%)**: O operador  (%) calcula o resto quando o operando esquerdo é dividido pelo operando direito. a % b
# 7. **Exponenciação ():\*\*** O operador duplo asterisco (**) eleva o operando esquerdo à potência do operando direito. a ** b
#
# O Python segue a ordem padrão de operações, o que significa que as operações entre parênteses são realizadas primeiro, seguidas de exponenciação, multiplicação e divisão (da esquerda para a direita) e, finalmente, adição e subtração (da esquerda para a direita).
#
# Além disso, o arrendondamento de números em python é feito com o método round(), respeitando a seguinte sintaxe
#
# `round(numero_decimal, quantidade_casas_decimais)`

# %%
(2 + 2) * 8 - 2
# Out:
# 30

# %%
#Exemplo de arrendodamento em 2 casas decimais
var = 19.2222
round(var, 1)
# Out:
# 19.2

# %% [markdown]
# ### Atividade 1- Uso de Números
#
# * Crie uma Varivel, de nome variavel_int, e armazene o valor inteiro 10. Crie uma segunda variável, de nome variavel_float, e armazene o valor float 12.3
# * Some a variavel_int com a variavel_float e armazene em uma nova variavel chamada de resultado. Apresente o valor da variável resultado na tela.
# * Multiplique o resultado pela variavel_float, armazenando o valor final na variável resultado. Apresente o valor da variável resultado na tela.
# * Divida o resultado pela variavel_int, armazenando o valor final na variável resultado. Apresente o valor da variável resultado na tela.
# * Eleve a variável resultado ao quadrado, armazenando o valor final na variável resultado. Apresente o valor da variável resultado na tela.

# %%
#Resposta Atividade 1 - Uso de Numeros

# %% [markdown]
# Independentemente dos tipos específicos, a divisão de dois números, mesmo que o resultado final seja um valor inteiro, resulta em um elemento do tipo float. Além disso, qualquer operação envolvendo ambos os tipos numéricos também resulta em um float.
#
# Para facilitar a legibilidade do código, o Python permite o uso de underscores para separar milhares em números muito grandes.

# %%
numero_grande = 1_000_000_000_000_000
print(numero_grande)
# Out:
# 1000000000000000

# %% [markdown]
# ### Atividade 2- Uso de Números
#
# Escreva um programa que calcule o Índice de Massa Corporal (IMC) a partir do peso e da altura de um usuário.
#
# O IMC é uma medida do peso de alguém levando em consideração sua altura. por exemplo. Se uma pessoa alta e uma pessoa baixa pesam a mesma quantidade, a pessoa baixa geralmente está mais acima do peso.
#
# O IMC é calculado dividindo o peso de uma pessoa (em kg) pelo quadrado da sua altura (em m):
#
# ![image.png](data:image/png;base64,...)
#
# A conversão de uma variável  string para int é realizda utilizado o metodo int(). Ex.
#
# ```
# var = '1'
# var_int = int(var)
# ```
#
# Já o método float() é utilizado para conversão para float.
#
# ```
# var = '1'
# var_float = floar(var)
# ```
#
# As entradas/saídas do programa devem se assimilar ao apresentao nas imagens abaixo.
#
# ![image.png](data:image/png;base64,...)
#
# **Dicas**
#
# * O programa deve aceitar variadas entradas de dados.
# * Lembre-se de converter os dados para int e float
# * O resultado de saída é um número inteiro

# %%
#Resposta da Atividade 2
# Out:
# Digite sua altura em m: 1.75
# Digite seu peso em kg: 85
# 27

# %% [markdown]
# # Projeto 1 - Calculadora
#
# Crie uma calculadora para calcular a conta em um bar.
#
# * Receba o número de pessoas na mesa
# * Receba o valor da conta
# * Divida o valor da conta pelo número de pessoas
# * Acrescente a gorjeta de 10% ao valor de cada pessoa.
# * Formate o resultado com 2 casas decimais = 33,60
# * Apresente o resultado na tela
#
#
#
#
# Dica: Não se esqueça de arredondar o número final para 2 casas decimais.💪
#
# A entrada e saída de dados deve apresentar o seguinte padrão
#
# ![image.png](data:image/png;base64,...)

# %%
#Resposta Projeto 1

# %% [markdown]
# ##1.3. Tipos de Dados Boleanos
#
# O tipo de dados boleano no python é representado pelo "bool" e assume apenas dois valores - True e False

# %%
#Crie duas variáveis, uma chamada valor_true cujo valor deve ser o boleano True, e uma chamada valor_false, que armazena o boleano False
valor_true = True
valor_false = False
